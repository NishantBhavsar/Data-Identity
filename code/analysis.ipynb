# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # <font id='toc' color='Tomato'><u>Table of content</u></font>
# <ol style="list-style-type: decimal;">
# <li><a href="#gad" style="text-decoration: none;"><font size='3px' color='tomato'>General analysis of data</font></a></li>
#     <ol style="list-style-type: decimal;">
#     <li><a href="#dtdi" style="text-decoration: none;"><font size='3px' color='purple'>Data types and data info</font></a></li>
#     <li><a href="#nor" style="text-decoration: none;"><font size='3px' color='purple'>Number of records</font></a></li>
#     <li><a href="#nan" style="text-decoration: none;"><font size='3px' color='purple'>NaN values</font></a></li>
#     <li><a href="#ttdc" style="text-decoration: none;"><font size='3px' color='purple'>Train-Test data check</font></a></li>
#     <li><a href="#dgpf" style="text-decoration: none;"><font size='3px' color='purple'>Distribution graph plot function</font></a></li>
#     <li><a href="#dov" style="text-decoration: none;"><font size='3px' color='purple'>Distribution of variables</font></a></li>
#         <ol style="list-style-type: decimal;">
#         <li><a href="#dv1" style="text-decoration: none;"><font size='3px' color='blue'>is_pass (target variable)</font></a></li>
#         <li><a href="#dv2" style="text-decoration: none;"><font size='3px' color='blue'>program_type</font></a></li>
#         <li><a href="#dv3" style="text-decoration: none;"><font size='3px' color='blue'>program_id</font></a></li>
#         <li><a href="#dv4" style="text-decoration: none;"><font size='3px' color='blue'>test_type</font></a></li>
#         <li><a href="#dv5" style="text-decoration: none;"><font size='3px' color='blue'>difficulty_level</font></a></li>
#         <li><a href="#dv6" style="text-decoration: none;"><font size='3px' color='blue'>program_duration</font></a></li>
#         <li><a href="#dv7" style="text-decoration: none;"><font size='3px' color='blue'>test_id</font></a></li>
#         <li><a href="#dv8" style="text-decoration: none;"><font size='3px' color='blue'>gender</font></a></li>
#         <li><a href="#dv9" style="text-decoration: none;"><font size='3px' color='blue'>education</font></a></li>
#         <li><a href="#dv10" style="text-decoration: none;"><font size='3px' color='blue'>city_tier</font></a></li>
#         <li><a href="#dv11" style="text-decoration: none;"><font size='3px' color='blue'>is_hendicapped</font></a></li>
#         <li><a href="#dv12" style="text-decoration: none;"><font size='3px' color='blue'>total_programs_enrolled</font></a></li>
#         <li><a href="#dv13" style="text-decoration: none;"><font size='3px' color='blue'>trainee_engagement_rating</font></a></li>
#         <li><a href="#dv14" style="text-decoration: none;"><font size='3px' color='blue'>age</font></a></li>
#         <li><a href="#dv15" style="text-decoration: none;"><font size='3px' color='blue'>trainee_id</font></a></li>
#         </ol>
#     </ol>
# <li><a href="#eda" style="text-decoration: none;"><font size='3px' color='tomato'>Exploratory data analysis</font></a></li>
# </ol>

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
train_df = pd.read_csv('data/train.csv') # load train dataset
test_df = pd.read_csv('data/test.csv') # load test dataset

# %% [markdown]
# # <font id='gad' color='tomato'>General Analysis of Data</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %% [markdown]
# ## <font id='dtdi' color='purple'>Data types and data information</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
# glimps of train data
train_df.head(10)
# Out:
#           id program_id program_type  program_duration  test_id test_type  \
# 0   9389_150        Y_1            Y               136      150   offline
# 1   16523_44        T_1            T               131       44   offline
# 2  13987_178        Z_2            Z               120      178    online
# 3   13158_32        T_2            T               117       32   offline
# 4   10591_84        V_3            V               131       84   offline
# 5   12531_23        T_3            T               134       23   offline
# 6  17874_144        Y_2            Y               120      144    online
# 7    8129_61        U_1            U               134       61    online
# 8    5652_57        U_1            U               134       57   offline
# 9  17019_153        Y_1            Y               136      153   offline
#
#   difficulty_level  trainee_id gender            education  city_tier   age  \
# 0     intermediate        9389      M        Matriculation          3  24.0
# ...

# %%
print("######## Train dataset info ########")
train_df.info()
print("\n######## Test dataset info ########")
test_df.info()
# Out:
# ######## Train dataset info ########
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73147 entries, 0 to 73146
# Data columns (total 16 columns):
# id                           73147 non-null object
# program_id                   73147 non-null object
# program_type                 73147 non-null object
# program_duration             73147 non-null int64
# test_id                      73147 non-null int64
# test_type                    73147 non-null object
# difficulty_level             73147 non-null object
# trainee_id                   73147 non-null int64
# gender                       73147 non-null object
# education                    73147 non-null object
# city_tier                    73147 non-null int64
# age                          45418 non-null float64
# total_programs_enrolled      73147 non-null int64
# is_handicapped               73147 non-null object
# trainee_engagement_rating    73070 non-null float64
# is_pass                      73147 non-null int64
# ...

# %% [markdown]
# ## <font id='nor' style="color:purple;">Number of records</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
def plot_num_of_record(kwargs):
    n_rows_data = []
    n_cols_data = []
    names = []
    n_rows_data_norm = []
    
    for name, df in kwargs.items():
        n_rows_data.append(df.shape[0])
        n_cols_data.append(df.shape[1])
        names.append(name)
    
    if len(names)!=0:
        for i in n_rows_data:
            n_rows_data_norm.append(round((i/sum(n_rows_data))*100, 2))
        
        fig, axs = plt.subplots(ncols=2, figsize=(8,6))
        fig.suptitle("Number of records In files")
        ax_rows = sns.barplot(names, n_rows_data, ax=axs[0])
        ax_rows.set(xlabel='Files', ylabel='Number of Rows')
        for n, da in enumerate(zip(names, n_rows_data)):
            if da[1]!=0:
                ax_rows.text(n, da[1], str(da[1]) + ",  " + str(n_rows_data_norm[n]) + " %", ha='center')
                
        ax_cols = sns.barplot(names, n_cols_data, ax=axs[1])
        ax_cols.set(xlabel='Files', ylabel='Number of Columns')
        for n, da in enumerate(zip(names, n_cols_data)):
            if da[1]!=0:
                ax_cols.text(n, da[1], da[1], va='center')
    else:
        print("no files are passed")

# %%
plot_num_of_record({'Train': train_df, 'Test': test_df})

# %% [markdown]
# ## <font id="nan" style="color:purple;">NaN values</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
def plot_nan(data, title, figsize):
    num_records = data.shape[0]
    cols = data.isnull().sum().index.values
    nans = data.isnull().sum().values.astype('int')
    
    fig, ax = plt.subplots(figsize=figsize)
    ax = sns.barplot(nans, cols, ax=ax)
    ax.set(xlabel='Number of NaNs', ylabel='Columns')
    ax.set_title(title)
    for n, da in enumerate(zip(cols, nans)):
        if da[1]!=0:
            ax.text(da[1], n, str(da[1]) + ", " + str(round(100*(da[1]/num_records), 2)) + " %", va='center', fontsize=10)

# %%
plot_nan(train_df, 'Train data NaN Values', (8,10))

# %%
plot_nan(test_df, 'Test data NaN Values', (8,10))

# %% [markdown]
# ## <font id='ttdc' color="purple">Check if values present in test file are also present in train file</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
from IPython.display import HTML, display, clear_output

# %%
def train_test_data_check(train_df, test_df, cols=None, use_all_cols=True):
    if cols == None:
        if use_all_cols:
            train_cols = set(train_df.columns)
            test_cols = set(test_df.columns)
            cols = train_cols.intersection(test_cols)
        else:
            train_cols = set(train_df.select_dtypes(['object', 'category']).columns)
            test_cols = set(test_df.select_dtypes(['object', 'category']).columns)
            cols = train_cols.intersection(test_cols)
        
    for i, col in enumerate(cols):
        display(HTML('<h3><font id="'+ col + '-ttdc' + '" color="blue">' + str(i+1) + ') ' + col + '</font></h3>'))
        print("Datatype : " + str(train_df[col].dtype) )
        print(str(train_df[col].dropna().nunique()) + " unique " + col  + " in Train dataset")
        print(str(test_df[col].dropna().nunique()) + " unique " + col  + " in Test dataset")
        extra = len(set(test_df[col].dropna().unique()) - set(train_df[col].dropna().unique()))
        print(str(extra) + " extra " + col + " in Test dataset")
        if extra == 0:
            display(HTML('<h5><font color="green"> All values present in Test dataset also present in Train dataset for column ' + col + '</font></h5>'))
        else:
            display(HTML('<h5><font color="green">' + str(extra) + ' ' +  col + ' are not present in Train dataset which are in Test dataset</font></h5>'))

# %%
train_test_data_check(train_df, test_df)
# Out:
# <h3><font id="trainee_id-ttdc" color="blue">1) trainee_id</font></h3>
# Datatype : int64
# 18500 unique trainee_id in Train dataset
# 14779 unique trainee_id in Test dataset
# 922 extra trainee_id in Test dataset
# <h5><font color="green">922 trainee_id are not present in Train dataset which are in Test dataset</font></h5>
# <h3><font id="program_type-ttdc" color="blue">2) program_type</font></h3>
# Datatype : object
# 7 unique program_type in Train dataset
# 7 unique program_type in Test dataset
# 0 extra program_type in Test dataset
# <h5><font color="green"> All values present in Test dataset also present in Train dataset for column program_type</font></h5>
# <h3><font id="age-ttdc" color="blue">3) age</font></h3>
# Datatype : float64
# 45 unique age in Train dataset
# 44 unique age in Test dataset
# 0 extra age in Test dataset
# <h5><font color="green"> All values present in Test dataset also present in Train dataset for column age</font></h5>
# ...

# %% [markdown]
# ### <font id='dgpf' color='gray'>Distribution graph plot function</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
def plot_bar_counts_categorical(data_se, title, figsize, sort_by_counts=False):
    info = data_se.value_counts()
    info_norm = data_se.value_counts(normalize=True)
    categories = info.index.values
    counts = info.values
    counts_norm = info_norm.values
    fig, ax = plt.subplots(figsize=figsize)
    if data_se.dtype in ['object']:
        if sort_by_counts == False:
            inds = categories.argsort()
            counts = counts[inds]
            counts_norm = counts_norm[inds]
            categories = categories[inds]
        ax = sns.barplot(counts, categories, orient = "h", ax=ax)
        ax.set(xlabel="count", ylabel=data_se.name)
        ax.set_title("Distribution of " + title)
        for n, da in enumerate(counts):
            ax.text(da, n, str(da)+ ",  " + str(round(counts_norm[n]*100,2)) + " %", fontsize=10, va='center')
    else:
        inds = categories.argsort()
        counts_sorted = counts[inds]
        counts_norm_sorted = counts_norm[inds]
        ax = sns.barplot(categories, counts, orient = "v", ax=ax)
        ax.set(xlabel=data_se.name, ylabel='count')
        ax.set_title("Distribution of " + title)
        for n, da in enumerate(counts_sorted):
            ax.text(n, da, str(da)+ ",  " + str(round(counts_norm_sorted[n]*100,2)) + " %", fontsize=10, ha='center')

# %%
def count_plot_by_hue(data_se, hue_se, title, figsize, sort_by_counts=False):
    if sort_by_counts == False:
        order = data_se.unique()
        order.sort()
    else:
        order = data_se.value_counts().index.values
    off_hue = hue_se.nunique()
    off = len(order)
    fig, ax = plt.subplots(figsize=figsize)
    ax = sns.countplot(y=data_se, hue=hue_se, order=order, ax=ax)
    ax.set_title(title)
    patches = ax.patches
    for i, p in enumerate(ax.patches):
        x=p.get_bbox().get_points()[1,0]
        y=p.get_bbox().get_points()[:,1]
        total = x
        p = i
        q = i
        while(q < (off_hue*off)):
            p = p - off
            if p >= 0:
                total = total + (patches[p].get_bbox().get_points()[1,0] if not np.isnan(patches[p].get_bbox().get_points()[1,0]) else 0)
            else:
                q = q + off
                if q < (off*off_hue):
                    total = total + (patches[q].get_bbox().get_points()[1,0] if not np.isnan(patches[q].get_bbox().get_points()[1,0]) else 0)
       
        perc = str(round(100*(x/total), 2)) + " %"
        
        if not np.isnan(x):
            ax.text(x, y.mean(), str(int(x)) + ",  " + perc, va='center')
    plt.show()

# %% [markdown]
# ## <font id='dov' color='purple'>Distribution of variables</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %% [markdown]
# ### <font id='dv1' color='blue'>is_pass (target variable)</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
plot_bar_counts_categorical(train_df['is_pass'], 'Pass', (8,8))

# %% [markdown]
# ##### <font color=green>70 % trainee qualified tests from Train dataset</font>

# %% [markdown]
# ### <font id='dv2' color='blue'>program_type</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
plot_bar_counts_categorical(train_df['program_type'], 'Train data : Program type', (8,8))

# %%
plot_bar_counts_categorical(test_df['program_type'], 'Test data : Program type', (8,8))

# %% [markdown]
# ##### <font color='green'>Train and Test datasets has same distribution for 'program_type' attribute</font>
# ##### <font color='green'>30 % of test recordes are of program_type Y and 25% are of program_type T</font>
# ##### <font color='green'>so, 45% of data is of program_type Y and T combined</font>
# ##### <font color='green'>This indicates that more trainees are taking tests of program_type Y & T</font>
# ##### <font color='green'>What could be the reason behind this????</font>

# %% [markdown]
# ### <font id='dv3' color='blue'>program_id</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
plot_bar_counts_categorical(train_df['program_id'], 'Train dataset: program_id', (10,12))

# %%
plot_bar_counts_categorical(test_df['program_id'], 'Test dataset: program_id ', (10,12))

# %% [markdown]
# ##### <font color='green'>Train and Test dataset has same distribution for 'program_id'</font>

# %% [markdown]
# ### <font id='dv4' color='blue'>test_type</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
plot_bar_counts_categorical(train_df['test_type'], 'Train dataset: test_type', (10,5))

# %%
plot_bar_counts_categorical(test_df['test_type'], 'Test dataset: test_type', (10,5))

# %% [markdown]
# ##### <font color='green'>Train and Test dataset has same distribution for 'test_type'</font>

# %% [markdown]
# ### <font id='dv5' color='blue'>difficulty_level</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
plot_bar_counts_categorical(train_df['difficulty_level'], 'Train dataset: difficulty_level', (10,6))

# %%
plot_bar_counts_categorical(test_df['difficulty_level'], 'Test dataset: difficulty_level', (10,6))

# %% [markdown]
# ##### <font color='green'>Train and Test datasets has same distribution for 'difficulty_level'</font>

# %% [markdown]
# ### <font id='dv6' color='blue'>program_duration</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %% [markdown]
# ##### <font color='green'>From <a href='#program_duration-ttdc'>here</a> we know that 'program_duration' has 10 distinct int values, same in both train and test dataset.<br>So, we can consider it as a categorical variable. </font>

# %%
plot_bar_counts_categorical(train_df['program_duration'], 'Train dataset: program_duration', (15, 10))

# %%
plot_bar_counts_categorical(test_df['program_duration'], 'Test dataset: program_duration', (15,10))

# %% [markdown]
# ##### <font color='green'>Train and Test dataset has same distribution for 'program_duration'</font>

# %% [markdown]
# ### <font id='dv7' color='blue'>test_id</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %% [markdown]
# ##### <font color='green'>From <a href='#test_id-ttdc'>here</a> we have 188 distinct test_id, same in both train and test dataset. <br> we can use it as an ordinal variable. Here is distribution plot.</font>

# %%
sns.distplot(train_df['test_id'])
plt.show()

# %%
print("minimum test_id = " + str(train_df['test_id'].min()) )
# Out:
# minimum test_id = 0

# %%
print("maximun test_id = " + str(train_df['test_id'].max()))
# Out:
# maximun test_id = 187

# %% [markdown]
# ##### <font color=green>There are 188 distinct ids with minimum 0 and maximum 187 </font>

# %% [markdown]
# ### <font id='dv8' color='blue'>gender</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
plot_bar_counts_categorical(train_df['gender'], 'Train dataset: gender', (10,5))

# %%
plot_bar_counts_categorical(test_df['gender'], 'Test dataset: gender', (10,5))

# %% [markdown]
# ##### <font color='green'>Train and Test dataset has same distribution for 'gender'.</font>
# ##### <font color='green'>There are 7% more Males than Females who took tests.</font>

# %% [markdown]
# ### <font id='dv9' color='blue'>education</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
plot_bar_counts_categorical(train_df['education'], 'Train dataset: education', (10, 7))

# %%
plot_bar_counts_categorical(test_df['education'], 'Test dataset: education', (10,7))

# %% [markdown]
# ### <font id='dv10' color='blue'>city_tier</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
plot_bar_counts_categorical(train_df['city_tier'], 'Train dataset: city_tier', (7, 7))

# %%
plot_bar_counts_categorical(test_df['city_tier'], 'Test dataset: city_tier', (7,7))

# %% [markdown]
# ### <font id='dv11' color='blue'>is_handicapped</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
plot_bar_counts_categorical(train_df['is_handicapped'], 'Train dataset: is_handicapped', (10,5))

# %%
plot_bar_counts_categorical(test_df['is_handicapped'], 'Test dataset: is_handicapped', (10,5))

# %% [markdown]
# ### <font id='dv12' color='blue'>total_programs_enrolled</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %%
plot_bar_counts_categorical(train_df['total_programs_enrolled'], 'Train dataset: total_programs_enrolled', (15,7))

# %%
plot_bar_counts_categorical(test_df['total_programs_enrolled'], 'Test dataset: total_programs_enrolled', (15,7))

# %% [markdown]
# ### <font id='dv13' color='blue'>trainee_engagement_rating</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %% [markdown]
# ##### <font color='green'>from <a href='#trainee_engagement_rating-ttdc'>this</a>, This variable is in float format.</font>
# ##### <font color='green'>and from <a href='#nan'>this</a>, Train and test dataset has 0.1%  NaN values for this variable</font>

# %%
plot_bar_counts_categorical(train_df['trainee_engagement_rating'], 'Train dataset: trainee_engagement_rating', (10,7))

# %%
plot_bar_counts_categorical(test_df['trainee_engagement_rating'], 'Test dataset: trainee_engagement_rating', (10,7))

# %% [markdown]
# ### <font id='dv14' color='blue'>age</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %% [markdown]
# ##### <font color='green'>From <a href='#nan'>this</a>, Train and Test dataset contains 38% NaN values for age column.</font>
# ##### <font color='green'>From <a href='#age-ttdc'>this</a>, 'age' column is in float format.</font>

# %%
print("minimum age in train dataset = " + str(train_df['age'].min()))
print("maximun age in train dataset = " + str(train_df['age'].max()))
# Out:
# minimum age in train dataset = 17.0
# maximun age in train dataset = 63.0

# %%
print('Distribution of age : Train dataset')
sns.distplot(train_df['age'].dropna())
plt.show()
# Out:
# Distribution of age : Train dataset

# %%
plot_bar_counts_categorical(train_df['age'], 'Train dataset: age', (20,10))

# %%
print("minimum age in test dataset = " + str(test_df['age'].min()))
print("maximun age in test dataset = " + str(test_df['age'].max()))
# Out:
# minimum age in test dataset = 17.0
# maximun age in test dataset = 63.0

# %%
print('Distribution of age : Test dataset')
sns.distplot(test_df['age'].dropna())
plt.show()
# Out:
# Distribution of age : Test dataset

# %%
plot_bar_counts_categorical(test_df['age'], 'Test dataset: age', (20,10))

# %% [markdown]
# ### <font id='dv15' color='blue'>trainee_id</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %% [markdown]
# ##### <font color='green'>From <a href='#trainee_id-ttdc'>this</a>, there are 922 trainee which are present in test data but not in train data.<br>So, in training a model we have to make features for trainee.<br>Train dataset has 18500 unique trainee and Test dataset has 14779 unique trainee.</font>

# %%
print("minimun trainee_id in train dataset = " + str(train_df['trainee_id'].min()))
print("maximum trainee_id in train dataset = " + str(train_df['trainee_id'].max()))
# Out:
# minimun trainee_id in train dataset = 1
# maximum trainee_id in train dataset = 20098

# %%
print("Distribution of trainee_id of train dataset")
sns.distplot(train_df['trainee_id'], kde=False)
plt.plot()
# Out:
# Distribution of trainee_id of train dataset
# []

# %%
print("minimun trainee_id in test dataset = " + str(test_df['trainee_id'].min()))
print("maximum trainee_id in test dataset = " + str(test_df['trainee_id'].max()))
# Out:
# minimun trainee_id in test dataset = 1
# maximum trainee_id in test dataset = 20098

# %%
print("Distribution of trainee_id of test dataset")
sns.distplot(test_df['trainee_id'], kde=False)
plt.show()
# Out:
# Distribution of trainee_id of test dataset

# %%
set(train_df['trainee_id'].unique()).union(set(test_df['trainee_id'].unique())) - set(range(1, 20099))
# Out:
# set()

# %% [markdown]
# ##### <font color='green'>Train and Test dataset has combined 20098 trainee, ids randing from 1 to 20098.<br>From this train dataset doesn't have 922 trainee which are only present in Test dataset.<br></font>

# %% [markdown]
#  # <font id='eda' color='tomato'>EDA</font><a href='#toc' style="text-decoration: none;margin-left:10px"><font size='3px' color='blue' title='Table of Content'>&#8624;</font></a>

# %% [markdown]
# ### <font color='blue'>program_type with target variable is_pass </font>

# %%
count_plot_by_hue(train_df['program_type'], train_df['is_pass'], 'Train dataset', (10,10))

# %% [markdown]
# ##### <font color='green'>trainee who takes test of program_type X, Y or Z has high chance of passing the test</font>

# %% [markdown]
# ### <font color='blue'>program_type with test_type</font>

# %%
count_plot_by_hue(train_df['program_type'], train_df['test_type'] , 'Train dataset', (10,10))

# %%
count_plot_by_hue(test_df['program_type'], test_df['test_type'], 'Test dataset', (10,10))

# %% [markdown]
# ##### <font color='green'>tests of program_type S & X are only in offline mode</font>
# ##### <font color='green'>Distribution of test_type by program_type is same for Train and Test datasets</font>

# %% [markdown]
# ### <font color='blue'>program_type with difficulty_level</font>

# %%
count_plot_by_hue(train_df['program_type'], train_df['difficulty_level'], 'Train dataset', (10,15))

# %%
count_plot_by_hue(test_df['program_type'], test_df['difficulty_level'], 'Test dataset', (10,15))

# %% [markdown]
# ##### <font color='green'>All tests of program_type 'Z' are has difficulty_level 'easy' in both Train and Test dataset</font>

# %% [markdown]
# ### <font color='blue'>program_type with </font>

# %% [markdown]
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

# %%
count_plot_by_hue(train_df['test_id'], train_df['is_pass'], 'Train dataset', (10,200))

# %% [markdown]
# ##  ### program_id

# %%
train_df['program_id'].nunique()
# Out:
# 22

# %%
test_df['program_id'].nunique()
# Out:
# 22

# %%
train_df['program_id'].unique()
# Out:
# array(['Y_1', 'T_1', 'Z_2', 'T_2', 'V_3', 'T_3', 'Y_2', 'U_1', 'Y_3',
#        'X_3', 'Y_4', 'V_1', 'T_4', 'Z_1', 'S_2', 'X_2', 'V_4', 'Z_3',
#        'U_2', 'X_1', 'S_1', 'V_2'], dtype=object)

# %%
test_df['program_id'].unique()
# Out:
# array(['T_1', 'Y_3', 'Y_2', 'V_4', 'U_1', 'T_3', 'V_1', 'T_4', 'Y_4',
#        'Z_2', 'Y_1', 'U_2', 'T_2', 'V_2', 'X_1', 'V_3', 'X_3', 'Z_3',
#        'S_1', 'Z_1', 'S_2', 'X_2'], dtype=object)

# %% [markdown]
# #### <div id="attribution" style="text-align: right; color:#999; background:#fff;">Created by <font color='Tomato'>Nishant Bhavsar</font>, Made with <font color='SlateBlue'>Jupyter</font>.</div>
